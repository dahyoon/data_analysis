# %% [markdown]
# ### 숙명여대 학과 정보 수집

# %%
# 필요한 모듈 참조
import requests
    # request로 갖고 온 데이터값이 JSON형태이면 dictionary로 변환하면 된다
    # request로 갖고 온 데이터값이 HTML + CSS 이면 BeautifulSoup라는 클래스를 통해 HTML + CSS 안에 있는 내용들을 추출해준다
from bs4 import BeautifulSoup
from pandas import DataFrame

# %%
# 접속개체 생성
session = requests.Session()

# 접속객체에 부가정보 (header) 삽입하기
session.headers.update({
    "Referer": "",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
})

# %%
# 대학번호 리스트 정의 --> URL을 분석해서 얻은 값
clist = [1011,1023,1030,1041,1046,1052,1054,1057,1062,1064,1070,1073,1076]

# %% [markdown]
# #### 응담결과로부터 데이터 추출하기

# %%
# 수집한 정보를 저장할 빈 리스트
학과목록_리스트 = []

# 대학 수 만큼 반복
for c in clist:
    # 수집할 컨텐츠가 있는 웹 페이지의 주소
    url = "https://www.sookmyung.ac.kr/sookmyungkr/%d/subview.do" % c

    # 생성한 접속객체를 활용하여 API에 접속
    r = session.get(url)

    # 접속에 실패한 경우
    if r.status_code != 200:
        # 에러코드와 에러메시지 출력
        msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
        # 에러를 강제로 생성시킴
        raise Exception (msg)

    r.encoding = "utf-8"
    soup = BeautifulSoup(r.text)
    
    college_list = soup.select(".college_list")
    # print (college_list)

    for item in college_list:
        # print(item)
        # print("-" * 50)

        # 학과 이름
        h5El = item.select("h5")
        name = h5El[0].text.strip()
        name
        
        # 상세보기 url
        # 가져온 페이지 주소의 예) /sookmyungkr/1012/subview.do
        # 같은 사이트 안에서 이동할 때는 앞부분 "https://www.sookmyung.ac.kr"을 생략 가능하나
        # 외부에서 직접 접근할 때는 반드시 전체 주소가 필요함
        # 가져온 값이 전체주소가 아니므로 검사하여 누락된 부분을 덧붙여야 한다
        viewEl = item.select(".view")
        view = viewEl[0].attrs["href"]

        if view.find("https://www.sookmyung.ac.kr") == -1:
            view = "https://www.sookmyung.ac.kr" + view
        # print(view)
        # print("-" * 50)
        
        # 학과 소개 pdf 
        pdfEl = item.select(".info")
        pdf = pdfEl[0].attrs['href']
        # print(pdf)
        # print("-" * 50)

        # 학과 홈페이지
        homepageEl = item.select(".homepage")
        homepage = homepageEl[0].attrs['href']
        # print(homepage)
        # print("-" * 50)

        # 수집한 값들을 딕셔너리로 묶은 후 리스트에 추가
        college_dict = {'학과이름': name, '상세페이지': view, '홈페이지': homepage}

        #------------------
        # 상세보기 URL을 새롭게 수집
        #-------------------
        r = session.get(view)

        if r.status_code != 200:
            # 에러코드와 에러메시지 출력
            msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
            print(msg)
            continue
        
        r.encoding = "utf-8"
        detailSoup = BeautifulSoup(r.text)
        # print(detailSoup)

        # 같은 구조를 갖는 전화번호, 팩스번호, 위치, 이메일주소를 가져온다
        infoEl = detailSoup.select(".college_info_data dl")
        # print(infoEl)
        # print("-" * 50)

        for info in infoEl:
            # print(info)
            dt = info.select("dt")[0].text.replace(':', "").strip()
            dd = info.select("dd")[0].text.replace(":", "").strip()
            # print(dt, dd)
            # print("-" * 50)
            college_dict[dt] = dd
        #--------------------
        # 상세보기 URL을 새롭게 수집 (끝)
        #--------------------
        학과목록_리스트.append(college_dict)

        # pdf 파일 다운로드
        # pdf의 URL을 저장하고 있는 변수는 pdf
        if pdf.find('.pdf') > -1:
            r = session.get(pdf, stream=True)
            if r.status_code == 200:
                r.encoding = "utf-8"
                with open("%s.pdf" % name, 'wb') as f:
                    f.write(r.raw.read())

df = DataFrame(학과목록_리스트)
df.to_excel("3_학과정보수집3.xlsx")
df
# Out:
#                       학과이름                                              상세페이지  \
# 0                   한국어문학부  https://www.sookmyung.ac.kr/sookmyungkr/1012/s...
# 1                   역사문화학과  https://www.sookmyung.ac.kr/sookmyungkr/1013/s...
# 2               프랑스언어ㆍ문화학과  https://www.sookmyung.ac.kr/sookmyungkr/1014/s...
# 3                   중어중문학부  https://www.sookmyung.ac.kr/sookmyungkr/1015/s...
# 4                독일언어ㆍ문화학과  https://www.sookmyung.ac.kr/sookmyungkr/1016/s...
# 5                     일본학과  https://www.sookmyung.ac.kr/sookmyungkr/1017/s...
# 6                   문헌정보학과  https://www.sookmyung.ac.kr/sookmyungkr/1018/s...
# 7          문화관광외식학부문화관광학전공  https://www.sookmyung.ac.kr/sookmyungkr/1020/s...
# 8     문화관광외식학부르꼬르동블루외식경영전공  https://www.sookmyung.ac.kr/sookmyungkr/1021/s...
# 9                     교육학부  https://www.sookmyung.ac.kr/sookmyungkr/1022/s...
# 10                     화학과  https://www.sookmyung.ac.kr/sookmyungkr/1024/s...
# 11                 생명시스템학부  https://www.sookmyung.ac.kr/sookmyungkr/1025/s...
# 12                     수학과  https://www.sookmyung.ac.kr/sookmyungkr/1026/s...
# 13                    통계학과  https://www.sookmyung.ac.kr/sookmyungkr/1027/s...
# 14                   체육교육과  https://www.sookmyung.ac.kr/sookmyungkr/1028/s...
# 15                     무용과  https://www.sookmyung.ac.kr/sookmyungkr/1029/s...
# 16                 화공생명공학부  https://www.sookmyung.ac.kr/sookmyungkr/1031/s...
# 17                 인공지능공학부  https://www.sookmyung.ac.kr/sookmyungkr/1033/s...
# 18  첨단소재·전자융합공학부지능형전자시스템전공  https://www.sookmyung.ac.kr/sookmyungkr/1034/s...
# 19     첨단소재·전자융합공학부신소재물리전공  https://www.sookmyung.ac.kr/sookmyungkr/1035/s...
# 20          소프트웨어학부컴퓨터과학전공  https://www.sookmyung.ac.kr/sookmyungkr/1037/s...
# 21        소프트웨어학부데이터사이언스전공  https://www.sookmyung.ac.kr/sookmyungkr/1038/s...
# 22                 기계시스템학부  https://www.sookmyung.ac.kr/sookmyungkr/1039/s...
# 23                   기초공학부  https://www.sookmyung.ac.kr/sookmyungkr/1040/s...
# 24                가족자원경영학과  https://www.sookmyung.ac.kr/sookmyungkr/1042/s...
# 25                  아동복지학부  https://www.sookmyung.ac.kr/sookmyungkr/1043/s...
# 26                    의류학과  https://www.sookmyung.ac.kr/sookmyungkr/1044/s...
# 27                  식품영양학과  https://www.sookmyung.ac.kr/sookmyungkr/1045/s...
# 28                  정치외교학과  https://www.sookmyung.ac.kr/sookmyungkr/1047/s...
# 29                    행정학과  https://www.sookmyung.ac.kr/sookmyungkr/1048/s...
# 30                  홍보광고학과  https://www.sookmyung.ac.kr/sookmyungkr/1049/s...
# 31                 소비자경제학과  https://www.sookmyung.ac.kr/sookmyungkr/1050/s...
# 32                  사회심리학과  https://www.sookmyung.ac.kr/sookmyungkr/1051/s...
# 33                     법학부  https://www.sookmyung.ac.kr/sookmyungkr/1053/s...
# 34                    경제학부  https://www.sookmyung.ac.kr/sookmyungkr/1055/s...
# 35                    경영학부  https://www.sookmyung.ac.kr/sookmyungkr/1056/s...
# 36                    피아노과  https://www.sookmyung.ac.kr/sookmyungkr/1058/s...
# 37                    관현악과  https://www.sookmyung.ac.kr/sookmyungkr/1059/s...
# 38                     성악과  https://www.sookmyung.ac.kr/sookmyungkr/1060/s...
# 39                     작곡과  https://www.sookmyung.ac.kr/sookmyungkr/1061/s...
# 40                     약학부  https://www.sookmyung.ac.kr/sookmyungkr/1063/s...
# 41              시각ㆍ영상 디자인과  https://www.sookmyung.ac.kr/sookmyungkr/1065/s...
# 42                  산업디자인과  https://www.sookmyung.ac.kr/sookmyungkr/1066/s...
# 43                  환경디자인과  https://www.sookmyung.ac.kr/sookmyungkr/1067/s...
# 44                     공예과  https://www.sookmyung.ac.kr/sookmyungkr/1068/s...
# 45                     회화과  https://www.sookmyung.ac.kr/sookmyungkr/1069/s...
# 46                  기초교양학부  https://www.sookmyung.ac.kr/sookmyungkr/1071/s...
# 47               융합학부/연계전공  https://www.sookmyung.ac.kr/sookmyungkr/1072/s...
# 48                 글로벌협력전공  https://www.sookmyung.ac.kr/sookmyungkr/1074/s...
# 49               앙트러프러너십전공  https://www.sookmyung.ac.kr/sookmyungkr/1075/s...
# 50                 영어영문학전공  https://www.sookmyung.ac.kr/sookmyungkr/1077/s...
# 51              테슬(TESL)전공  https://www.sookmyung.ac.kr/sookmyungkr/1078/s...
#
#                                           홈페이지                전화  \
# 0              https://korean.sookmyung.ac.kr/       02-710-9310
# 1             https://history.sookmyung.ac.kr/  02-710-9361,9367
# 2               http://french.sookmyung.ac.kr/  02-710-9329,9292
# 3             https://chinese.sookmyung.ac.kr/       02-710-9335
# 4              https://german.sookmyung.ac.kr/       02-710-9342
# 5               https://japan.sookmyung.ac.kr/       02-710-9885
# 6                 https://lis.sookmyung.ac.kr/       02-710-9373
# 7   https://cultureandtourism.sookmyung.ac.kr/       02-710-9969
# 8                 https://lcb.sookmyung.ac.kr/      02-2077-7335
# 9                 https://edu.sookmyung.ac.kr/       02-710-9355
# 10                http://chem.sookmyung.ac.kr/       02-710-9413
# 11                 http://bio.sookmyung.ac.kr/       02-710-9419
# 12                http://math.sookmyung.ac.kr/       02-710-9425
# 13                http://stat.sookmyung.ac.kr/       02-710-9437
# 14            http://movement.sookmyung.ac.kr/  02-710-9840/9444
# 15                     http://dance-smu.co.kr/       02-710-9450
# 16                 http://cbe.sookmyung.ac.kr/      02-2077-7469
# 17                  http://it.sookmyung.ac.kr/       02-710-9379
# 18             http://electro.sookmyung.ac.kr/      02-2077-7860
# 19             http://physics.sookmyung.ac.kr/       02-710-9407
# 20               http://csweb.sookmyung.ac.kr/       02-710-9431
# 21                  http://ds.sookmyung.ac.kr/       02-710-9296
# 22                 http://mse.sookmyung.ac.kr/      02-2077-7862
# 23               http://basic.sookmyung.ac.kr/      02-2077-7855
# 24              http://family.sookmyung.ac.kr/       02-710-9457
# 25        http://childwelfare.sookmyung.ac.kr/       02-710-9477
# 26               http://cloth.sookmyung.ac.kr/       02-710-9463
# 27                  http://fn.sookmyung.ac.kr/       02-710-9470
# 28            http://politics.sookmyung.ac.kr/       02-710-9488
# 29                  http://pa.sookmyung.ac.kr/       02-710-9499
# 30                http://prad.sookmyung.ac.kr/       02-710-9734
# 31             http://conecon.sookmyung.ac.kr/       02-710-9525
# 32         https://www.socpsy.sookmyung.ac.kr/      02-2077-7621
# 33                 http://law.sookmyung.ac.kr/       02-710-9494
# 34                http://econ.sookmyung.ac.kr/       02-710-9507
# 35                 http://biz.sookmyung.ac.kr/  02-710-9513,9519
# 36             http://music.sookmyung.ac.kr/30       02-710-9534
# 37             http://music.sookmyung.ac.kr/29       02-710-9559
# 38             http://music.sookmyung.ac.kr/31       02-710-9533
# 39             http://music.sookmyung.ac.kr/32       02-710-9532
# 40            http://pharmacy.sookmyung.ac.kr/       02-710-9576
# 41                http://smvd.sookmyung.ac.kr/       02-710-9958
# 42                          http://smid.ac.kr/       02-710-9582
# 43              http://design.sookmyung.ac.kr/       02-710-9758
# 44               http://craft.sookmyung.ac.kr/       02-710-9583
# 45             http://fineart.sookmyung.ac.kr/       02-710-9658
# 46                 http://gei.sookmyung.ac.kr/      02-2077-7511
# 47                 http://gei.sookmyung.ac.kr/      02-2077-7509
# 48              http://global.sookmyung.ac.kr/      02-2077-7496
# 49              http://global.sookmyung.ac.kr/      02-2077-7578
# 50              http://english.sookmyung.ac.kr       02-710-9321
# 51              http://english.sookmyung.ac.kr       02-710-9321
#
#                              팩스           위치                             이메일
# 0                  02-2077-7310       순헌관411          km9310@sookmyung.ac.kr
# 1                  02-2077-7311       순헌관412   histo-culture@sookmyung.ac.kr
# 2                  02-2077-7314       순헌관314          french@sookmyung.ac.kr
# 3                  02-2077-7315       순헌관311       china9335@sookmyung.ac.kr
# 4                  02-2077-7316      순헌관316B          dokmun@sookmyung.ac.kr
# 5                  02-2077-7313       순헌관602         smjapan@sookmyung.ac.kr
# 6                   02-710-9276       순헌관220          an9377@sookmyung.ac.kr
# 7                  02-2077-7319       새힘관205           ctour@sookmyung.ac.kr
# 8                  02-2077-7319       새힘관205             lcb@sookmyung.ac.kr
# 9                  02-2077-7317       순헌관921             edu@sookmyung.ac.kr
# 10                 02-2077-7321       과학관101            chem@sookmyung.ac.kr
# 11                 02-2077-7322       과학관101             bio@sookmyung.ac.kr
# 12                 02-2077-7323   사회교육관 416호            math@sookmyung.ac.kr
# 13                  02-710-9283     사회교육관512            stat@sookmyung.ac.kr
# 14               0303-0799-0369       진리관304        movement@sookmyung.ac.kr
# 15                  02-710-9848       진리관302       andyd9450@sookmyung.ac.kr
# 16                 02-2077-7450       과학관463        chembioe@sookmyung.ac.kr
# 17                  02-710-9704       명신관513          itdept@sookmyung.ac.kr
# 18                          NaN  르네상스플라자 501         electro@sookmyung.ac.kr
# 19                 02-2077-7320       과학관209          ca9407@sookmyung.ac.kr
# 20                  02-710-9296       명신관425        computer@sookmyung.ac.kr
# 21                  02-710-9296       명신관425        software@sookmyung.ac.kr
# 22                 02-2077-7863  르네상스플라자 501        mechasys@sookmyung.ac.kr
# 23                          NaN  르네상스플라자 501           basic@sookmyung.ac.kr
# 24                 02-2077-7327       순헌관323          family@sookmyung.ac.kr
# 25                  02-710-9209       순헌관323    childwelfare@sookmyung.ac.kr
# 26                 02-2077-7324       순헌관323       cloth9463@sookmyung.ac.kr
# 27                  02-710-9479       순헌관323          fn9470@sookmyung.ac.kr
# 28                  02-710-9648       순헌관313        politics@sookmyung.ac.kr
# 29                  02-710-9713       순헌관313          ec9499@sookmyung.ac.kr
# 30               0303-0799-0380       순헌관312            prad@sookmyung.ac.kr
# 31               0303-0799-0393       순헌관312         conecon@sookmyung.ac.kr
# 32               0303-0799-0397       순헌관721          socpsy@sookmyung.ac.kr
# 33  02-710-9838, 0303-0799-0377       진리관209           smlaw@sookmyung.ac.kr
# 34                 02-2077-7328       순헌관315          fa9507@sookmyung.ac.kr
# 35                  02-710-9527      순헌관316A        business@sookmyung.ac.kr
# 36               0303-0799-0342        음대201          ga9534@sookmyung.ac.kr
# 37                  02-710-9558        음대201          gb9559@sookmyung.ac.kr
# 38                 02-2077-7371        음대201          gc9533@sookmyung.ac.kr
# 39                  02-710-9558        음대201          gd9532@sookmyung.ac.kr
# 40                  02-710-9871       약학관205       pharm9576@sookmyung.ac.kr
# 41                  02-710-9588       미술대210            smvd@sookmyung.ac.kr
# 42                  02-710-9588       미술대210            smid@sookmyung.ac.kr
# 43                  02-710-9588       미술대210            smed@sookmyung.ac.kr
# 44                  02-710-9588       미술대210           craft@sookmyung.ac.kr
# 45                  02-710-9588       미술대210         fineart@sookmyung.ac.kr
# 46                 02-2077-7514      행정관 201            general_edu@sm.ac.kr
# 47                 02-2077-7514      행정관 201     convergence@sookmyung.ac.kr
# 48               0303-0799-0352   수련교수회관 507   globalservice@sookmyung.ac.kr
# 49               0303-0799-0352   수련교수회관 507   globalservice@sookmyung.ac.kr
# 50                  02-710-9380       진리관303  english-office@sookmyung.ac.kr
# 51                  02-710-9380       진리관303  english-office@sookmyung.ac.kr
