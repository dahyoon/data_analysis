# %% [markdown]
# # 변수, 텐서, 계산 그래프
#
# ## 1. 작업준비
# - tensorflow 설치 필요
#     - 터미널에 `pip install --upgrade tensorflow`

# %%
import os
os.getcwd()
path = os.path.abspath(os.__file__)
path
# Out:
# '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/os.py'

# %%
import tensorflow as tf
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## 2. 변수의 이해
# - 프로그램에서의 변수와는 개념이 다르다. 학습을 위한 가설이 다음과 같이 있다면,
#
# $f(x) = W * x + b$
#
# - 입력 데이터가 $x$ 일 때 $W$ 와 $b$ 는 텐서플로우가 학습을 통해 스스로 구해야 하는 값이다.
# - 이를 `변수(Variable)`라고 하는데, 변수형은 Variable 타입의 객체로 생성된다.
# - 변수는 생성할 때 그 값에 따라 `암묵적 타입`과 `명시적 타입`으로 구분된다.
#
# ### 1) `암묵적 타입`의 변수 생성하기
# - `tf.Variable(n)`
#     - n = 숫자

# %%
x = tf.Variable(123)
tf.print(x)

y = tf.Variable(x + 100)
tf.print(y)

# %% [markdown]
# ### 2) `명시적 타입`의 변수 생성하기
# - `tf.Variable()` 함수에 데이터 타입을 의미하는 `dtype 파라미터`를 전달한다

# %%
x = tf.Variable(123, dtype=tf.float32)
tf.print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x = tf.Variable(123, dtype=tf.float32)
#       2 tf.print(x)
#
# NameError: name 'tf' is not defined

# %% [markdown]
# ### 3) 데이터 타입의 종류
# - tf.float16: 16-bit half precision floating-point
# - tf.float32: 32-bit single-precision floating-point.
# - tf.float64: 64-bit double-precision floating-point.
# - tf.bfloat16: 16-bit truncated floating-point.
# - tf.complex64: 64-bit single-precision complex.
# - tf.complex128: 128-bit double-precision complex.
# - tf.int8: 8-bit signed integer.
# - tf.int16: 16-bit signed integer.
# - tf.int32: 32-bit signed integer.
# - tf.int64: 64-bit signed integer.
# - tf.uint8: 8-bit unsigned integer.
# - tf.uint16: 16-bit unsigned integer.
# - tf.uint32: 32-bit unsigned integer.
# - tf.uint64: 64-bit unsigned integer.
# - tf.bool: Boolean.
# - tf.string: String.
# - tf.qint8: Quantized 8-bit signed integer.
# - tf.quint8: Quantized 8-bit unsigned integer.
# - tf.qint16: Quantized 16-bit signed integer.
# - tf.quint16: Quantized 16-bit unsigned integer.
# - tf.qint32: Quantized 32-bit signed integer.
# - tf.resource: Handle to a mutable resource.
# - tf.variant: Values of arbitrary types.
#
# ## 3. Tensor 텐서
# - 텐서란 `배열의 집합`을 의미하며 배열의 `차수`에 따라 불리는 `이름이 바뀐`다.
# - 파이썬에서는 텐서를 numpy array로 표현함
# |이름|설명|
# |--|--|
# |Tensor|수학적인 개념으로 데이터의 배열을 의미|
# |Rank|텐서의 차원(Dimension); numpy의 shape값으로 확인 가능|
#
# ### 0) 배열의 종류
# |Rank|Type|설명|E.g.|
# |--|--|--|--|
# |0|scalar|랭크가 0인 배열; 원소가 1개인 1차 배열|[1]|
# |1|vextor|원소가 2개 이상인 1차 배열|[1, 2]|
# |2|matrix|2차 배열|[ [1,2] , [3,4] ]|
# |3|tensor|3차 배열|[ [ [-1,-2] , [1,2] ] , [ [-1,0] , [1,0] ] ]|
# |n|n-tensor|n차 배열||

# %%
from IPython.display import display, Image
display(Image('image15_tensor.png'))

# %% [markdown]
# ### 1) Scalar 스칼라 (랭크가 0일 배열)

# %%
a = 100
tsl = np.array(a)
print(tsl.shape)
tsl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 a = 100
# ----> 2 tsl = np.array(a)
#       3 print(tsl.shape)
#       4 tsl
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### 2) Vector 백터 (랭크가 1인 배열)

# %%
b = [1, 2, 3]
ts2 = np.array(b)
print(ts2.shape)
ts2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 b = [1, 2, 3]
# ----> 2 ts2 = np.array(b)
#       3 print(ts2.shape)
#       4 ts2
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### 3) Matrix 행렬 (랭크가 2인 배열)

# %%
c = [[10, 20, 30], [100, 200, 300]]
ts3 = np.array(c)
print(ts3.shape)
ts3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 c = [[10, 20, 30], [100, 200, 300]]
# ----> 2 ts3 = np.array(c)
#       3 print(ts3.shape)
#       4 ts3
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### 4) Tensor 텐서 (랭크가 3인 배열)

# %%
hello = [ [-1, -2, -3], [1, 2, 3] ]
world = [ [-1, 0, 1], [1, 0, -1] ]
d = [ hello, world ]
ts4 = np.array(d)
print(ts4.shape)
ts4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 world = [ [-1, 0, 1], [1, 0, -1] ]
#       3 d = [ hello, world ]
# ----> 4 ts4 = np.array(d)
#       5 print(ts4.shape)
#       6 ts4
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## 4. 계산 그래프 (이진 그래프)

# %%
from IPython.display import display, Image
display(Image('image16_node.png'))

# %% [markdown]
# - Computational Graph
# - 컴퓨터 공학에서 정의하는 노드 (Node)와 엣지 (Edge)로 이루어진 자료구조
# - 텐서들이 계산 그래프 구조를 통해 노드에서 노드로 이동한다
# - `텐서플로우 라이브러리`는 그래프 구조를 먼저 정의하고, 정의한 그래프에 실제 텐서들을 흘려보내도록 디자인 되었다.
#
# ### 1) 명시적 타입을 갖는 노드 정의
# - print() 함수로 출력할 경우 노드의 정보만 출력될 뿐 실제 값이 출력되지는 않는다
# - 실제 값을 확인하기 위해서는 `tf.print()` 함수를 사용해야 함

# %%
node1 = tf.constant(3.0, dtype=tf.float32, name = 'hello')
print(node1)
tf.print(node1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 node1 = tf.constant(3.0, dtype=tf.float32, name = 'hello')
#       2 print(node1)
#       3 tf.print(node1)
#
# NameError: name 'tf' is not defined

# %% [markdown]
# ### 2) 암묵적 타입을 갖는 노드 정의

# %%
node2 = tf.constant(4.0, name='world')
print(node2)
tf.print(node2)

# %% [markdown]
# ### 3) 두 개의 노드의 값을 더하는 연산을 수행하는 node3를 정의

# %%
node3 = tf.add(node1, node2)
print(node3)
tf.print(node3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 node3 = tf.add(node1, node2)
#       2 print(node3)
#       3 tf.print(node3)
#
# NameError: name 'tf' is not defined
