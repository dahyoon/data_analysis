# %% [markdown]
# # 카카오 책 검색 (반복처리)
# > 출판사에 근무하는 당신은 이번에 새로 출간할 "파이썬 프로그래밍" 서적에 대한 시장조사를 수행해야 한다.

# %%
# 필요한 모듈 참조

# request 모듈, 결과 json, pandas라는 패키지 안의 DataFrame이라는 클래스를 갖고 옴
# DataFrame - 딕셔너리를 포함하는 리스트를 표 형태로 만들어줄 때 씀; 엑셀 시트 같이 생긴 자료구조
import requests
import json
from pandas import DataFrame

# %%
# 접속할 URL
urlFmt = "https://dapi.kakao.com/v3/search/book?query={query}&page={page}&size={size}"

# %%
# 요청변수
query = "파이썬"
page = 1
size = 10
# key = "직적발급받은 key"
key = "f903e6bb99d409d576298b6e08527c66"

# %%
# 접속 객체 생성
session = requests.Session()

# 접속객체에 부가정보(header) 삽입하기
session.headers.update({
    "Authorization": "KakaoAK %s" % key # 인증키
})

# %%
# 다음 페이지가 존재하는지 여부 -> 이 값이 False인 동안은 반복
isEnd = False

# 반복 수행 도중 추출되는 검색결과 리스트를 결합할 빈 리스트 준비
mylist = []

# 1 페이지부터 시작
page = 1

while not isEnd:
    # -----------------------------------------
    # 이전 예제 코드 시작
    # -----------------------------------------
    # 접속할 URL
    url = urlFmt.format(query=query, page=page, size = size)
    # 생성한 접속객체를 활용하여 API에 접속
    r = session.get(url)
    # 접속에 실패한 경우
    if r.status_code != 200:
        # 에러코드와 에러메시지 출력
        msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
        # 에러를 강제로 생성시킴
        raise Exception(msg)

    # 인코딩 형식 지정
    r.encoding = "utf-8"
    # 가져온 문자열을 딕셔너리로 변환
    data = json.loads(r.text)
    data
    # -----------------------------------------
    # 이전 예제 코드 끝
    # -----------------------------------------

    # 검색 결과를 갖고 있는 딕셔너리를 포함하는 리스트 추출
    searchList = data['documents']
    # 추출한 리스트("documents")의 원소(딕셔더리들)들을 미리 준비한 빈 리스트에 추가
    mylist.extend(searchList)

    # 
    isEnd = bool(data['meta']['is_end'])
    page += 1
    print("isEnd=", isEnd, ", 다음 페이지=", page)

print("최종 검색 건수: %d" % len(mylist))
# Out:
# isEnd= False , 다음 페이지= 2
# isEnd= False , 다음 페이지= 3
# isEnd= False , 다음 페이지= 4
# isEnd= False , 다음 페이지= 5
# isEnd= False , 다음 페이지= 6
# isEnd= False , 다음 페이지= 7
# isEnd= False , 다음 페이지= 8
# isEnd= False , 다음 페이지= 9
# isEnd= False , 다음 페이지= 10
# isEnd= False , 다음 페이지= 11
# isEnd= False , 다음 페이지= 12
# isEnd= False , 다음 페이지= 13
# isEnd= False , 다음 페이지= 14
# isEnd= False , 다음 페이지= 15
# isEnd= False , 다음 페이지= 16
# isEnd= False , 다음 페이지= 17
# isEnd= False , 다음 페이지= 18
# isEnd= False , 다음 페이지= 19
# isEnd= False , 다음 페이지= 20
# isEnd= False , 다음 페이지= 21
# isEnd= False , 다음 페이지= 22
# isEnd= False , 다음 페이지= 23
# isEnd= False , 다음 페이지= 24
# isEnd= False , 다음 페이지= 25
# isEnd= False , 다음 페이지= 26
# isEnd= False , 다음 페이지= 27
# isEnd= False , 다음 페이지= 28
# isEnd= False , 다음 페이지= 29
# isEnd= False , 다음 페이지= 30
# isEnd= False , 다음 페이지= 31
# isEnd= False , 다음 페이지= 32
# isEnd= False , 다음 페이지= 33
# isEnd= False , 다음 페이지= 34
# isEnd= False , 다음 페이지= 35
# isEnd= False , 다음 페이지= 36
# isEnd= False , 다음 페이지= 37
# isEnd= False , 다음 페이지= 38
# isEnd= False , 다음 페이지= 39
# isEnd= False , 다음 페이지= 40
# isEnd= False , 다음 페이지= 41
# isEnd= False , 다음 페이지= 42
# isEnd= False , 다음 페이지= 43
# isEnd= False , 다음 페이지= 44
# isEnd= False , 다음 페이지= 45
# isEnd= False , 다음 페이지= 46
# isEnd= False , 다음 페이지= 47
# isEnd= False , 다음 페이지= 48
# isEnd= False , 다음 페이지= 49
# isEnd= False , 다음 페이지= 50
# isEnd= False , 다음 페이지= 51
# isEnd= False , 다음 페이지= 52
# isEnd= False , 다음 페이지= 53
# isEnd= False , 다음 페이지= 54
# isEnd= False , 다음 페이지= 55
# isEnd= False , 다음 페이지= 56
# isEnd= False , 다음 페이지= 57
# isEnd= False , 다음 페이지= 58
# isEnd= False , 다음 페이지= 59
# isEnd= False , 다음 페이지= 60
# isEnd= False , 다음 페이지= 61
# isEnd= False , 다음 페이지= 62
# isEnd= False , 다음 페이지= 63
# isEnd= False , 다음 페이지= 64
# isEnd= False , 다음 페이지= 65
# isEnd= False , 다음 페이지= 66
# isEnd= False , 다음 페이지= 67
# isEnd= False , 다음 페이지= 68
# isEnd= False , 다음 페이지= 69
# isEnd= False , 다음 페이지= 70
# isEnd= False , 다음 페이지= 71
# isEnd= False , 다음 페이지= 72
# isEnd= False , 다음 페이지= 73
# isEnd= False , 다음 페이지= 74
# isEnd= False , 다음 페이지= 75
# isEnd= False , 다음 페이지= 76
# isEnd= False , 다음 페이지= 77
# isEnd= False , 다음 페이지= 78
# isEnd= False , 다음 페이지= 79
# isEnd= False , 다음 페이지= 80
# isEnd= False , 다음 페이지= 81
# isEnd= False , 다음 페이지= 82
# isEnd= False , 다음 페이지= 83
# isEnd= False , 다음 페이지= 84
# isEnd= False , 다음 페이지= 85
# isEnd= False , 다음 페이지= 86
# isEnd= False , 다음 페이지= 87
# isEnd= False , 다음 페이지= 88
# isEnd= False , 다음 페이지= 89
# isEnd= False , 다음 페이지= 90
# isEnd= False , 다음 페이지= 91
# isEnd= False , 다음 페이지= 92
# isEnd= False , 다음 페이지= 93
# isEnd= False , 다음 페이지= 94
# isEnd= False , 다음 페이지= 95
# isEnd= False , 다음 페이지= 96
# isEnd= False , 다음 페이지= 97
# isEnd= False , 다음 페이지= 98
# isEnd= False , 다음 페이지= 99
# isEnd= False , 다음 페이지= 100
# isEnd= True , 다음 페이지= 101
# 최종 검색 건수: 1000

# %%
# 결과 엑셀 저장 및 출력
df = DataFrame(mylist)
df.to_excel("6_카카오책검색결과(%s).xlsx" % query)
df
# Out:
#                   authors                                           contents  \
# 0                   [윤인성]  『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이...
# 1                   [박응용]  개정 2판으로 새롭게 태어났다! 챗GPT를 시작으로 펼쳐진 생성 AI 시대에 맞춰 ...
# 2                   [박응용]  문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개정판으...
# 3                  [나도코딩]  유튜브와 인프런 최고의 인기 강의를 한 권에 담았습니다. 일상 속 재미있는 예제로 ...
# 4                   [윤인성]  이 책은 독학으로 프로그래밍 언어를 처음 배우려는 입문자가, 혹은 파이썬을 배우려는...
# ..                    ...                                                ...
# 995        [Jones Martin]
# 996              [이브 힐피시]
# 997        [Briggs Jason]
# 998  [Spacagna Gianmario]
# 999                    []
#
#                           datetime                      isbn  price  \
# 0    2022-06-01T00:00:00.000+09:00  1162245654 9791162245651  22000
# 1    2023-06-15T00:00:00.000+09:00  1163034738 9791163034735  22000
# 2    2019-06-20T00:00:00.000+09:00  1163030910 9791163030911  18800
# 3    2023-02-20T00:00:00.000+09:00  1140703307 9791140703302  24000
# 4    2019-06-10T00:00:00.000+09:00  1162241888 9791162241882  18000
# ..                             ...                       ...    ...
# 995  2015-01-21T00:00:00.000+09:00  1492346136 9781492346135  43060
# 996  2019-01-10T00:00:00.000+09:00  1492024333 9781492024330  92820
# 997  2012-12-19T00:00:00.000+09:00  1593274076 9781593274078  45640
# 998  2017-04-28T00:00:00.000+09:00  1786464454 9781786464453  47000
# 999  2014-04-03T00:00:00.000+09:00             9781107631090  32459
#
#             publisher  sale_price status  \
# 0               한빛미디어       19800   정상판매
# 1             이지스퍼블리싱       19800   정상판매
# 2             이지스퍼블리싱       16920   정상판매
# 3                  길벗       21600   정상판매
# 4               한빛미디어       16200   정상판매
# ..                ...         ...    ...
# 995       CreateSpace       42970   정상판매
# 996    O'Reilly Media       83320   정상판매
# 997   No Starch Press       41240   정상판매
# 998  Packt Publishing       46530   정상판매
# 999                         32792   정상판매
#
#                                              thumbnail                  title  \
# 0    https://search1.kakaocdn.net/thumb/R120x174.q8...            혼자 공부하는 파이썬
# 1    https://search1.kakaocdn.net/thumb/R120x174.q8...        Do it! 점프 투 파이썬
# 2    https://search1.kakaocdn.net/thumb/R120x174.q8...        Do it! 점프 투 파이썬
# 3    https://search1.kakaocdn.net/thumb/R120x174.q8...   코딩 자율학습 나도코딩의 파이썬 입문
# 4    https://search1.kakaocdn.net/thumb/R120x174.q8...            혼자 공부하는 파이썬
# ..                                                 ...                    ...
# 995  https://search1.kakaocdn.net/thumb/R120x174.q8...  Python for Biologists
# 996  https://search1.kakaocdn.net/thumb/R120x174.q8...     Python for Finance
# 997  https://search1.kakaocdn.net/thumb/R120x174.q8...        Python for Kids
# 998  https://search1.kakaocdn.net/thumb/R120x174.q8...   Python Deep Learning
# 999  https://search1.kakaocdn.net/thumb/R120x174.q8...     Coding Club Python
#
#     translators                                                url
# 0            []  https://search.daum.net/search?w=bookpage&book...
# 1            []  https://search.daum.net/search?w=bookpage&book...
# 2            []  https://search.daum.net/search?w=bookpage&book...
# 3            []  https://search.daum.net/search?w=bookpage&book...
# 4            []  https://search.daum.net/search?w=bookpage&book...
# ..          ...                                                ...
# 995          []  https://search.daum.net/search?w=bookpage&book...
# 996          []  https://search.daum.net/search?w=bookpage&book...
# 997          []  https://search.daum.net/search?w=bookpage&book...
# 998          []  https://search.daum.net/search?w=bookpage&book...
# 999          []  https://search.daum.net/search?w=bookpage&book...
#
# [1000 rows x 12 columns]
