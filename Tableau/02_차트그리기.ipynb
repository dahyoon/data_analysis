# %% [markdown]
# # 태블로에서 차트 그리기
# ## I. 바 차트, 라인 차트, 영역 차트
# ### [1] 바 차트 Bar
# - Super Store 데이터 불러와서 Region별로 Sales 보여주는 바 차트 만들기
#     - 열/행 선반에 Region과 Sales를 추가하면 태블로는 저절로 바 차트를 생성 (바 차트가 가장 적합한 표현방식이라고 태블로가 자체 판단 후 선택했기 때문이다)
#     - 표현방식 바꾸기: '마크' 박스 안에 있는 '자동' 클릭 후 원하는 표현방식 선택
# - 눈에 잘 보이는 바 차트 만들기
#     1) `불필요한 필드 레이블 숨기기`
#         - Region이라는 레이블을 숨기고 싶은 경우: 레이블 우클릭 > 열에 대한 필드 레이블 숨기기 클릭
#     2) `축 머리글 표시 해제 후 레이블 직접 붙이기`
#         - Sales 값들을 나타내는 y축 머리글을 숨기고 싶은 경우: y축 레이블 칸 우클릭 > 머리글 표시 클릭 해제
#         - 바 위에 레이블 표시하고 싶은 경우: 위 아이콘들 중 T 써져있는 '마크 레이블 표시' 클릭
#     3) `불필요한 참조선 없애기`
#         - 배경에 있는 격조선(grid) 없애고 싶은 경우: 시트 배경 우클릭 > 서식... > '라인' 아이콘 클릭 > 행 > 격자선: 없음 선택
#         - y축에 있는 축 눈금자 없애고 싶은 경우: 시트 배경 우클릭 > 서식... > '라인' 아이콘 클릭 > 시트 > 축 눈금자: 없음 선택
#     4) `0이 되는 기준선 표시하기`
#         - 웬만하면 이 선을 표시하는 것 권장 - 이 선이 없으면 바 차트가 허공에 둥둥 떠다니는 느낌을 줌
#         - 0이 되는 기준선 표시하고 싶은 경우: 시트 배경 우클릭 > 서식... > 시트 > 영(0) 기준선: 원하는 스타일 선택
#     5) `(필요에 따라) 불투명도 조절하기` - 눈의 피로감 조절
#         - '마크' 박스 안에 있는 '색상' 박스 클릭 > 불투명도 > 원하는 만큼 불투명하게 설정 가능
#     6) `(필요에 따라) 짙은 색상의 테두리 활용` - 더 선명하게 보이기 위해
#         - '마크' 박스 안에 있는 '색상' 박스 클릭 > 효과 > 테두리: 원하는 색상 설정 가능
# ### [2] 라인 차트 Line
# - 전체적인 흐름/트렌드를 보기에 적합한 차트 타입
# - Super Store 데이터 불러와서 Order Date별로 Sales 보여주는 바 차트 만들기
#     - 열/행 선반에 Order Date와 Sales를 추가하면 태블로는 저절로 라인 차트를 생성 (라인 차트가 가장 적합한 표현방식이라고 태블로가 자체 판단 후 선택했기 때문이다)
#     - 날짜 필드 (년(Order Date)) 앞의 + 기호: 날짜 데이터의 계층 구조를 의미
#         - 날짜 데이터의 계층 구조: 연 - (분기) - 월 - 일 - 시 - 분 - 초
#         - + 클릭 시 현재 나와있는 '년' 다음인 '분기' 별 데이터로 나옴
#         - 한 번 더 + 클릭 시 다음인 '월' 별 데이터로 나옴, 다음은 '일' 별 데이터로 나옴
# - 연도 + 월 별 데이터로 보고 싶은 경우: 년(Order Date)와 월(Order Date)를 열에 놓기
#     - 결과:
# <img src="image1_divided.png" width="50%" >
# - 연도 + 월 별로 나뉘어져 있는 데이터들을 `월 별로 연결`되게 보고 싶은 경우:
#     - 월(Order Date) 우클릭 > 위쪽항목 월에 표시되어 있는 것을 확인 > 아래족 항목 월 클릭 (이럴 경우 불연속형 데이터를 연속형 데이터로 변환)
#         - 위쪽 항목 (년, 분기 ~ 더보기): 불연속형
#         - 아래쪽 항목 (년, 분기 ~ 더보기): 연속형
#     - 열 선반에 있는 년(Order Date) 필드 제거
#     - 결과:
# <img src="image2_connected.png" width="50%" >
#
# - 눈에 잘 보이는 라인 차트 만들기
#     1) `불필요한 필드 레이블 숨기기`
#         - x축의 - Month of Order Date라는 레이블을 숨기고 싶은 경우: 레이블 우클릭 > 축 편집 ... > 일반 > 축 제목 > 제목 > Month of Order Date 지우고 Enter
#     2) `머리글 표시 해제하여 축 숨기기/표시하기`
#         - Sales 값들을 나타내는 y축 머리글을 숨기고 싶은 경우: y축 레이블 칸 우클릭 > 머리글 표시 클릭하여 해제
#         - 다시 나타내고 싶은 경우: 행 선반에서 해당 필드 (합계(Sales)) 우클릭 > 머리글 표시 클릭하여 다시 표시
#     3) `불필요한 참조선 없애기`
#         - 배경에 있는 격조선(grid) 없애고 싶은 경우: 시트 배경 우클릭 > 서식... > '라인' 아이콘 클릭 > 행 > 격자선: 없음 선택
#         - y축에 있는 축 눈금자 없애고 싶은 경우: 시트 배경 우클릭 > 서식... > '라인' 아이콘 클릭 > 시트 > 축 눈금자: 없음 선택
#     4) `필요한 항목에 적절히 레이블링 하기`
#         - 지점 위에 레이블 표시하고 싶은 경우: 위 아이콘들 중 T 써져있는 '마크 레이블 표시' 클릭 (이럴 경우 월 별 레이블이 표시됨)
#         - 더 깔끔하게 원하는 항목만 레이블링 하고 싶은 경우: 왼쪽 '마크' 박스 > '레이블' 박스 > 레이블 지정할 마크 > 최소/최대 혹은 라인끝 등 원하는 항목 설정
#             - 라인끝 같은 경우 옵션 > '선 시작 레이블 지정' 을 해제하여 맨 마지막 월 데이터만 레이블링 가능
#     5) `(필요에 따라) 라인의 두께, 색상, 마커를 적절히 조정`
#         - '마크' 박스 >
#             - 색상 >
#                 - `색상 설정 가능`
#                 - 효과 > 마커: 선 위에 동그라미 점들로 `마커 표시 가능`
#             - 크기 > `두께 설정 가능`
# ### [3] 영역 차트 Area
# - Super Store 데이터 불러와서 월(Order Date)별로 Sales 보여주는 바 차트 만들기
#     - 열/행 선반에 Order Date와 Sales를 추가하면 태블로는 저절로 라인 차트를 생성 (라인 차트가 가장 적합한 표현방식이라고 태블로가 자체 판단 후 선택했기 때문이다)
#     - 년(Order Date) 필드 우클릭 > 아래쪽 항목에 있는 '월' 선택 (이러면 연속형 데이터의 월 별 Sales 데이터가 표시될 것이다)
#     - '마크' 박스 > 자동을 '영역'으로 설정 (영역 차트로 변경됨)
# - 추가적으로 제품의 Category 별로 Order Date별 Sales 보여주는 차트 만들기 (한 그래프 안에 다 포함)
#     - Category를 '마크' 박스 안에 있는 '색상' 박스에 끌어당기기:
# <img src="image3_add.png" width="50%" >
#     - 결과:
# <img src="image4_area.png" width="50%" >
# - 라인 차트와 영역 차트의 차이점
#     - 추가적으로 Category 별 데이터를 위와 같은 방법으로 추가할 경우:
#         - 영역 차트는 default로 누적된 값을 보여준다
#         - 라인 보여주는 것이 아니라 값 그대로를 보여준다:
# <img src="image5_line.png" width="50%" >
# - 누적된 값 설정/해제 방법:
#     - 맨 위 메뉴에서 '분석' > 마크 누적 > 설정/해제
#
# ## II. 비율을 나타내는 차트 (파이 차트 & 비율 바 차트)
# ### [4] 파이 차트
# ## III. 상관 관계와 분포를 나타내는 차트
# ### [5] 스캐터 플롯
# ### [6] 박스 플롯
# ### [7] 히스토그램
# ### [8] 하이라이트 테이블
# ### [9] 기타
