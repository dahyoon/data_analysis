# %% [markdown]
# # 네이버 쇼핑 상품 목록 수집
#
# ## 1. 패키지 참조

# %%
# ChromeDriver 자동 설치 모듈
import chromedriver_autoinstaller
# Chrome을 제어하기 위한 객체
from selenium import webdriver
# Chrome이 웹 페이지 로딩을 완료 할 때까지 최대 n초간 대기하는 기능.
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
from pandas import DataFrame
# 파이썬 프로그램에 지정된 시간동안 랙을 거는 기능을 위해 사용
import time
# 한글을 URL에 포함시킬 수 있도록 인코딩 해주는 모듈
from urllib import parse

# %% [markdown]
# ## 2. 크롬브라우저 가동하기

# %%
# 크롬드라이버 자동 설치
chromedriver_autoinstaller.install()

# 크롬드라이버를 통해 크롬을 실행시킴
# -> driver 객체는 Chrome 자체
driver = webdriver.Chrome()

# 크롬브라우저가 준비될 때 까지 최대 5초씩 대기
driver.implicitly_wait(5)

# %% [markdown]
# ## 3. 수집할 URL 준비

# %%
# 검색어
keyword = "노트북"

# 검색어를 URL에 포함시킬 수 있는 형태로 인코딩 --> URLEncoding
encKeyword = parse.quote(keyword)

# 네이버 쇼핑 검색 URL
urlFmt = "https://search.shopping.naver.com/search/all?query={keyword}"
url = urlFmt.format(keyword=encKeyword)
url
# Out:
# 'https://search.shopping.naver.com/search/all?query=%EB%85%B8%ED%8A%B8%EB%B6%81'

# %%
# 크롬브라우저로 방문시킴
driver.get(url)
time.sleep(1)

# %% [markdown]
# ## 4. Javascript 가동을 위한 샘플 코드

# %%
# 웹 브라우저의 현재 스크롤바 높이를 가져옴
height = int(driver.execute_script("return document.body.scrollHeight"))
height
# Out:
# 2846

# %%
# 화면의 맨 아래로 강제 스크롤 시키기
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %% [markdown]
# ## 5. 이후 페이지 코드를 수집하는 내용 구현하기

# %%
driver.page_source
# Out:
# '<html lang="ko"><head><meta name="viewport" content="width=device-width"><meta charset="utf-8"><title>노트북 : 네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/img/favicon.ico"><meta property="og:title" content="노트북 : 네이버 쇼핑"><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"><meta property="og:description" content="\'노트북\'의 네이버쇼핑 검색 결과입니다"><meta name="next-head-count" content="7"><link rel="preconnect" href="https://static.nid.naver.com"><link rel="preconnect" href="https://lcs.naver.com"><link rel="preconnect" href="http://shopping.phinf.naver.net"><link rel="preconnect" href="https://ssl.pstatic.net"><link rel="preconnect" href="https://shopping-phinf.pstatic.net"><link rel="preconnect" href="https://volts.shopping.naver.com"><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/4a5990d4d27855bc.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/4a5990d4d27855bc.css" data-n-g=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/f84a19becb34584a.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/f84a19becb34584a.css" data-n-p=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/54db74340c99d94a.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/54db74340c99d94a.css" data-n-p=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/f18c98c38eb3f309.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/f18c98c38eb3f309.css" data-n-p=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/7e44965a08f8c602.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/7e44965a08f8c602.css" data-n-p=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/d132b58116128d02.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/d132b58116128d02.css"><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/ad6694c03395b564.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/css/ad6694c03395b564.css"><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/chunks/1117.934363c2b7a0adbf.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/chunks/3502.3c34eea29f09b8bb.js"></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/chunks/webpack-9f638e76556f1398.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/chunks/framework-2ba54a73108076ed.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/chunks/main-7191483071d7e180.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_next/static/chunks/pages/_app-831bbe3879e3a190.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-240111-112116/_ne ...
